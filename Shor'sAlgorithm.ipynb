# %% [markdown]
# <center><h1>Shor's Algorithm: Period of a function and non-trivial square roots</h1></center>
#
# <center><p>Landneyker Betancourth</p></center>

# %% [markdown]
# # RSA system:

# %% [markdown]
# RSA System (Rivest, Shamir, Adleman): Public key cryptographic system that uses integer factoring.
# <center>
# <p>$p$, $q$ prime numbers</p>
# <p>$n=pq$</p>
# <p>$\theta=(p-1)(q-1)$</p>
# <p>$e$ co-prime of $\theta$ -> $GCD=1$</p>
# <p>$d=inv(e,\theta)$ -> $ed=1mod\theta$</p>
# <p>$(e,n)$ public key</p>
# <p>$(d,n)$ private key</p>
# <p>$c=m^e(n)$</p>
# <p>$m=c^d(n)$</p>
# </center>

# %% [markdown]
# Example:
#
# <center>
# <p>$p=5$, $q=11$</p>
# <p>$n=55$</p>
# <p>$\theta=40$</p>
# <p>$e=3$ co-prime of $\theta$ -> $GCD=1$</p>
# <p>$3d=1mod40$</p>
# <p>$d=27$ -> $81mod40=1$</p>
# <p>$(3,55)$ public key</p>
# <p>$(27,55)$ private key</p>
# <p>$m=2$</p>
# <p>$c=2^3(55)=8$</p>
# <p>$m=8^27(55)=2$</p>
# </center>

# %%
print('C = 8 mod (55):', 8 % 55)
print('m= 8^27 mod (55):', 8 ** 27 % 55)
# Out:
# C = 8 mod (55): 8
# m= 8^27 mod (55): 2

# %%
rsa_250 = 2140324650240744961264423072839333563008614715144755017797754920881418023447140136643345519095804679610992851872470914587687396261921557363047454770520805119056493106687691590019759405693457452230589325976697471681738069364894699871578494975937497937
len(str(rsa_250))
# Out:
# 250

# %% [markdown]
# However, performing factorization on rsa_250 requires a supercomputer and around 2700 core-years, which eventually yields the following two factors.
#
# Core year: Is the equivalent of using 1 CPU core continuosly for a full year, 12 cores for a month or 365 cores for a single day.

# %%
p = 64135289477071580278790190170577389084825014742943447208116859632024532344630238623598752668347708737661925585694639798853367
q = 33372027594978156556226010605355114227940760344767554666784520987023841729210037080257448673296881877565718986258036932062711
p*q
# Out:
# 2140324650240744961264423072839333563008614715144755017797754920881418023447140136643345519095804679610992851872470914587687396261921557363047454770520805119056493106687691590019759405693457452230589325976697471681738069364894699871578494975937497937

# %% [markdown]
# Factoring problem:
#
# Let ${\displaystyle N\in \mathbb {N}}$. Then, find a factor ${\displaystyle x\in \mathbb {N}}$, is find a solution for:
#
# $${\displaystyle \mathrm {mod} {(x^{2},N)}=1\,\,\,}$$
#
# That is, we need to find a $x$, such that when dividing its square by $N$, the remainder is 1.

# %% [markdown]
# # Shor's Algorithm:

# %% [markdown]
# Shor's algorithm can be divided into two parts:
#
# 1) Quantum part: find the period of a function (QFT).
#
# 2) Classic part: decompose a number into prime factors.

# %% [markdown]
# Theorem 1: given $N$, find the non-trivial square root of $N$, is equivalent to finding $p$ and $q$, $(N=pq)$.
#
# $$X^2\equiv1(N), X\in[2,N-2]$$
#
# $$X^2-1\equiv0(N)$$
#
# $$(X-1)(X+1)\equiv0(N)$$
#
# $$(X-1)(X+1)\equiv{KN}\text{, K multiple of N}$$
#
# $$(X-1)<N\equiv{p}$$
#
# $$(X+1)<N\equiv{q}$$
#
#
# Now:
#
# $$m^r\equiv1(N)\text{, r is the period should be 2}$$
#
#
# Theorem 2: given a number between $(2,N-2)$, the probability that the period $r$ be pair is $>50\%$.

# %% [markdown]
# Period finding:
#
# The algorithm to find the Shor period is based on quantum superposition. To compute the period of a function f, we evaluate the function at all points simultaneously.
#
# However, quantum physics does not allow us to have access to all this information directly. A quantum measurement will give only one of all possible values, destroying all the others.
#
# Implementation problems:
#
# * Create a superposition of states. This can be done by applying the Hadamard gates to all qubits in the check-in. Another approach would be to use the quantum Fourier transform (see below).
#
# * Implement the function f as a quantum transform. To achieve this, Shor used exponentiation by squares for his modular exponentiation transformation.
#
# * Perform a quantum Fourier transform. Using NOT controlled gates and single qubit rotation gates, Shor designed a circuit for the quantum Fourier transform that uses exactly ((logN) 2) gates.

# %% [markdown]
# Example:
#
# For $N=15$, choose a number $x$ between $[2, N-2]$.
#
# $$x=2$$
# $$2mod15=2$$
# $$2^2mod15=4$$
# $$2^3mod15=8$$
# $$2^4mod15=1$$
#
# Then $2^4$ can be expressed as $4^2$, for period $r=2$.
#
# $$x=4$$
# $$x+1=5\text{equivalent to }p$$
# $$x-1=3\text{equivalent to }q$$
# $$pq=N$$
# $$3*5=15$$

# %% [markdown]
# Big O Complexity: $O(n2^n)$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <img src="https://github.com/mtreinish/qiskit-workshop/blob/master/qiskit-heading.png?raw=1" alt="Drawing" style="width: 300px;"/>

# %%
# !pip install qiskit
# !pip install pylatexenc
# Out:
# ...
#      |████████████████████████████████| 6.0MB 24.1MB/s
# ...
#      |████████████████████████████████| 18.0MB 177kB/s
# ...
#      |████████████████████████████████| 235kB 42.4MB/s
# ...
#      |████████████████████████████████| 215kB 49.2MB/s
# ...
#      |████████████████████████████████| 2.1MB 31.0MB/s
# ...
#      |████████████████████████████████| 51kB 8.3MB/s
# ...
#      |████████████████████████████████| 1.5MB 37.1MB/s
# ...
#      |████████████████████████████████| 194kB 44.4MB/s
# ...
#      |████████████████████████████████| 71kB 8.8MB/s
# ...
#      |████████████████████████████████| 614kB 40.3MB/s
# ...
#      |████████████████████████████████| 3.2MB 31.1MB/s
# ...
#      |████████████████████████████████| 6.3MB 33.3MB/s
# ...
#   Created wheel for qiskit: filename=qiskit-0.27.0-cp37-none-any.whl size=10505 sha256=90e0b62e2059a6b3463779ab4dec0da391d738a5f567d6552ba4b3f76cd761c9
#   Stored in directory: /root/.cache/pip/wheels/c6/54/d9/f0f711dc20aff31947456951374132d0e23ec527da8c15295d
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from qiskit import QuantumCircuit, Aer, transpile, assemble, execute
from qiskit.tools.monitor import job_monitor
from qiskit.visualization import plot_histogram, plot_bloch_vector, plot_bloch_multivector
from math import gcd, pi
from numpy.random import randint
import pandas as pd
from fractions import Fraction
import pylatexenc
# %matplotlib inline

# %% [markdown]
# Period finding (QFT): Time domain to frequency domain.
#
# The quantum Fourier transform (QFT) is the quantum implementation of the discrete Fourier transform over the amplitudes of a wavefunction.
#
# The quantum Fourier transform (QFT) transforms between two bases, the computational (Z) basis, and the Fourier basis. The H-gate is the single-qubit QFT, and it transforms between the Z-basis states $|0⟩$ and $|1⟩$ to the X-basis states $|+⟩$ and $|−⟩$. In the same way, all multi-qubit states in the computational basis have corresponding states in the Fourier basis. The QFT is simply the function that transforms between these bases.
#
# $$|\text{State in Computational Basis}\rangle \quad \xrightarrow[]{\text{QFT}} \quad |\text{State in Fourier Basis}\rangle$$
#
# $$\text{QFT}|x\rangle = |\widetilde{x}\rangle$$
#
# $$\begin{aligned}
# QFT_N\vert x \rangle & = \frac{1}{\sqrt{N}}
# \left(\vert0\rangle + e^{\frac{2\pi i}{2}x} \vert1\rangle\right)
# \otimes
# \left(\vert0\rangle + e^{\frac{2\pi i}{2^2}x} \vert1\rangle\right)
# \otimes
# \ldots
# \otimes
# \left(\vert0\rangle + e^{\frac{2\pi i}{2^{n-1}}x} \vert1\rangle\right)
# \otimes
# \left(\vert0\rangle + e^{\frac{2\pi i}{2^n}x} \vert1\rangle\right)
# \end{aligned}$$

# %%
plot_bloch_vector([0,1,0], title="Bloch Sphere")

# %% [markdown]
# We will start off by creating the function that rotates our qubits correctly:
#
# Now we have correctly rotated the most significant qubit, we need to correctly rotate the second most significant qubit. Then we must deal with the third most significant, and so on.

# %%
def qft_rotations(circuit, n):
    """Performs qft on the first n qubits in circuit (without swaps)"""
    if n == 0:
        return circuit
    n -= 1
    circuit.h(n)
    for qubit in range(n):
        circuit.cp(pi/2**(n-qubit), qubit, n)
    # At the end of our function, we call the same function again on
    # the next qubits (we reduced n by one earlier in the function)
    qft_rotations(circuit, n)

# %% [markdown]
# We need to add the swaps at the end of the QFT function to match the definition of the QFT:

# %%
def swap_registers(circuit, n):
    for qubit in range(n//2):
        circuit.swap(qubit, n-qubit-1)
    return circuit

# %% [markdown]
# We will combine this into the final function `qft()`:

# %%
def qft(circuit, n):
    """QFT on the first n qubits in circuit"""
    qft_rotations(circuit, n)
    swap_registers(circuit, n)
    #circuit.name = 'QFT†'
    return circuit

# %%
# Let's see how it looks:
qc = QuantumCircuit(4)
qft(qc,4)
qc.draw('mpl')

# %% [markdown]
# We now want to demonstrate this circuit works correctly. To do this we must first encode a number in the computational basis. We can see the number 5 in binary is 101:

# %%
bin(5)
# Out:
# '0b101'

# %%
# Create the circuit
qc = QuantumCircuit(3)
# Encode the state 5
qc.x(0)
qc.x(2)
qc.draw('mpl')

# %% [markdown]
# And let's check the qubit's states using the statevector simulator:

# %%
sim = Aer.get_backend("aer_simulator")
qc_init = qc.copy()
qc_init.save_statevector()
statevector = sim.run(qc_init).result().get_statevector()
plot_bloch_multivector(statevector)

# %% [markdown]
# Finally, let's use our QFT function and view the final state of our qubits:

# %%
qft(qc,3)
qc.draw('mpl')

# %% [markdown]
# We can see out QFT function has worked correctly. Compared the state $|˜0⟩=|+++⟩$, Qubit $0$ has been rotated by $\tfrac{5}{8}$ of a full turn, qubit 1 by $\tfrac{10}{8}$ full turns (equivalent to $\tfrac{1}{4}$ of a full turn), and qubit $2$ by $\tfrac{20}{8}$ full turns (equivalent to $\tfrac{1}{2}$ of a full turn).

# %%
qc.save_statevector()
statevector = sim.run(qc).result().get_statevector()
plot_bloch_multivector(statevector)

# %% [markdown]
# **Running QFT on a Real Quantum Device:**
#
# If we tried running the circuit on a real device, the results would be completely random, since all qubits are in equal superposition of $|0⟩$ and $|1⟩$. If we want to demonstrate and investigate the QFT working on real hardware, we can instead create the state $|˜5⟩$, run the QFT in reverse, and verify the output is the state $|5⟩$ as expected.
#
# Firstly, let’s use Qiskit to easily reverse our QFT operation:

# %%
def inverse_qft(circuit, n):
    """Does the inverse QFT on the first n qubits in circuit"""
    # First we create a QFT circuit of the correct size:
    qft_circ = qft(QuantumCircuit(n), n)
    # Then we take the inverse of this circuit
    invqft_circ = qft_circ.inverse()
    # And add it to the first n qubits in our existing circuit
    circuit.append(invqft_circ, circuit.qubits[:n])
    return circuit.decompose() # .decompose() allows us to see the individual gates

# %% [markdown]
# Now let's put our qubits in the state $|˜5⟩$:

# %%
nqubits = 3
number = 5
qc = QuantumCircuit(nqubits)
for qubit in range(nqubits):
    qc.h(qubit)
qc.p(number*pi/4,0) # p is a phase gate (rotation)
qc.p(number*pi/2,1)
qc.p(number*pi,2)

qc.draw('mpl')

# %% [markdown]
# And we can see this does indeed result in the Fourier state $|˜5⟩$:

# %%
qc_init = qc.copy()
qc_init.save_statevector()
sim = Aer.get_backend("aer_simulator")
statevector = sim.run(qc_init).result().get_statevector()
plot_bloch_multivector(statevector)

# %% [markdown]
# Finally, let's apply our inverse QFT:

# %%
#style = {'backgroundcolor': 'lightgreen'}
#qc.draw('mpl', style=style)

# %%
qc = inverse_qft(qc, nqubits)
qc.measure_all()
qc.draw('mpl')

# %% [markdown]
# We see that the highest probability outcome is 101.

# %%
backend = Aer.get_backend('aer_simulator')
shots = 2048
transpiled_qc = transpile(qc, backend, optimization_level=3)
job = backend.run(transpiled_qc, shots=shots)
job_monitor(job)
counts = job.result().get_counts()
print(counts)
plot_histogram(counts)
# Out:
# Job Status: job has successfully run
# {'101': 2048}

# %% [markdown]
# In this example we will solve the period finding problem for $a=7$ and $N=15$. We provide the circuits for $U$ where:
#
# $$U|y\rangle = |ay\bmod 15\rangle$$
#
# To create $U^x$, we will simply repeat the circuit $x$ times. The function `c_amod15` returns the controlled-U gate for a, repeated power times.

# %%
def c_amod15(a, power):
    """Controlled multiplication by a mod 15"""
    if a not in [2,7,8,11,13]:
        raise ValueError("'a' must be 2,7,8,11 or 13")
    U = QuantumCircuit(4)        
    for iteration in range(power):
        if a in [2,13]:
            U.swap(0,1)
            U.swap(1,2)
            U.swap(2,3)
        if a in [7,8]:
            U.swap(2,3)
            U.swap(1,2)
            U.swap(0,1)
        if a == 11:
            U.swap(1,3)
            U.swap(0,2)
        if a in [7,11,13]:
            for q in range(4):
                U.x(q)
    U = U.to_gate()
    U.name = "%i^%i mod 15" % (a, power)
    c_U = U.control()
    return c_U

# %% [markdown]
# We will use 8 counting qubits:

# %%
# Specify variables
n_count = 8  # number of counting qubits
a = 7

# %% [markdown]
# With these building blocks we can easily construct the circuit for Shor's algorithm:

# %%
# Create QuantumCircuit with n_count counting qubits
# plus 4 qubits for U to act on
qc = QuantumCircuit(n_count + 4, n_count)

# Initialize counting qubits
# in state |+>
for q in range(n_count):
    qc.h(q)
    
# And auxiliary register in state |1>
qc.x(3+n_count)

# Do controlled-U operations
for q in range(n_count):
    qc.append(c_amod15(a, 2**q), 
             [q] + [i+n_count for i in range(4)])

# Do inverse-QFT
#qc.append(qft_dagger(n_count), range(n_count))
qft(qc, n_count)

# Measure circuit
qc.measure(range(n_count), range(n_count))
#qc.measure_all()
qc.draw('mpl', fold=-1)  # -1 means 'do not fold'

# %% [markdown]
# Let's see what results we measure:

# %%
aer_sim = Aer.get_backend('aer_simulator')
t_qc = transpile(qc, aer_sim)
qobj = assemble(t_qc)
results = aer_sim.run(qobj,shots=2048).result()
counts = results.get_counts()
plot_histogram(counts)

# %% [markdown]
# Tthese results correspond to measured phases of:

# %%
rows, measured_phases = [], []
for output in counts:
    decimal = int(output, 2)  # Convert (base 2) string to decimal
    phase = decimal/(2**n_count)  # Find corresponding eigenvalue
    measured_phases.append(phase)
    # Add these values to the rows in our table:
    rows.append([f"{output}(bin) = {decimal:>3}(dec)", 
                 f"{decimal}/{2**n_count} = {phase:.2f}"])
# Print the rows in a table
headers=["Register Output", "Phase"]
df = pd.DataFrame(rows, columns=headers)
#print(df)
df
# Out:
#             Register Output           Phase
# 0  11000000(bin) = 192(dec)  192/256 = 0.75
# 1  01000000(bin) =  64(dec)   64/256 = 0.25
# 2  10000000(bin) = 128(dec)  128/256 = 0.50
# 3  00000000(bin) =   0(dec)    0/256 = 0.00

# %% [markdown]
# The order (r) must be less than N, so we will set the maximum denominator to be 15:

# %%
rows = []
for phase in measured_phases:
    frac = Fraction(phase).limit_denominator(15)
    rows.append([phase, f"{frac.numerator}/{frac.denominator}", frac.denominator])
# Print as a table
headers=["Phase", "Fraction", "Guess for r"]
df = pd.DataFrame(rows, columns=headers)
#print(df)
df
# Out:
#    Phase Fraction  Guess for r
# 0   0.75      3/4            4
# 1   0.25      1/4            4
# 2   0.50      1/2            2
# 3   0.00      0/1            1

# %% [markdown]
# We can see that two of the measured eigenvalues provided us with the correct result: $r=4$, and we can see that Shor’s algorithm has a chance of failing. These bad results are because $s=0$, or because $s$ and $r$ are not coprime and instead of $r$ we are given a factor of $r$. The easiest solution to this is to simply repeat the experiment until we get a satisfying result for  $r$.

# %% [markdown]
# Exmaple:
#
# For $7^x\text{ mod }15$

# %%
def _7mod15():
    circ = QuantumCircuit(8)
    circ.x(4)
    circ.cx(0,5)
    circ.cx(0,6)
    circ.cx(1,4)
    circ.cx(1,6)
    for i in range(4,8):
        circ.ccx(0,1,i)
    gate = circ.to_gate()
    gate.name = "7^x mod 15"
    return gate

# %%
def QFT(n):
    qft_circ = QuantumCircuit(n)
    for i in range(n-1, -1, -1):
        qft_circ.h(i)
        
        for j in range(i - 1, -1, -1): 
            qft_circ.cu1(pi/(2 ** (i - j)), j, i)
 
        
    for i in range(n // 2):
        qft_circ.swap(i, n - i - 1)
    gate = qft_circ.to_gate()
    gate.name = "QFT" + str(n)
    return  gate

# %%
circ = QuantumCircuit(8,4)
circ.h(range(4))
circ.append(_7mod15(), range(8))
circ.measure(range(4,8),range(4))
circ.barrier(range(8))
#qft(qc, 4)
circ.append(QFT(4), range(4))
circ.measure(range(4), range(4))
circ.draw(output = 'mpl')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: The QuantumCircuit.cu1 method is deprecated as of 0.16.0. It will be removed no earlier than 3 months after the release date. You should use the QuantumCircuit.cp method instead, which acts identically.
#   import sys

# %%
backend = Aer.get_backend("qasm_simulator")
job = execute(circ, backend, shots = 2048)
result = job.result()
counts = result.get_counts()
plot_histogram(counts)

# %% [markdown]
# The values are: 0, 4, 8, 12 and the GCD for this values is 4:

# %%
counts
# Out:
# {'0000': 505, '0100': 512, '1000': 541, '1100': 490}

# %%
import math

firs_factor = math.gcd(4-1, 15)
sec_factor = math.gcd(4+1, 15)
print('Prime factors:', firs_factor, 'and', sec_factor)
# Out:
# Prime factors: 3 and 5

# %% [markdown]
# ## Referencias:
#
# Qiskit: https://qiskit.org/
#
# * Shor's Algorithm.
# * Quantum Fourier Transform.
